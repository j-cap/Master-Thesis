# %%
# %load_ext autoreload

# %%
# %autoreload 2
# %aimport stareg

# %%
from test import foo
foo()
# Out:
# 44

# %%
import numpy as np
import plotly.graph_objects as go
import stareg

# %%
from stareg import Bspline as BS

# %%
x = np.linspace(0,1,205)

# %%
d = BS.basismatrix(X=x, l=5)
# Out:
# MEEEE

# %%
fig = go.Figure()
for i in range(10):
    fig.add_trace(go.Scatter(x=x, y=d["basis"][:,i]))
fig.show()
