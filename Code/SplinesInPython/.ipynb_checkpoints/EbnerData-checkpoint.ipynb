# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import os, sys
from sklearn.model_selection import train_test_split
from stareg.star_model import StarModel

# %% [markdown]
# ### load data

# %%
path = "..\\..\\Data\\Table_alpha_Data.txt"
df = pd.read_csv(filepath_or_buffer=path)
df.columns = ["QDot", "T", "HTC"]

# %% [markdown]
# ### preprocessing and train-test-split

# %%
df_train, df_test = train_test_split(df[["QDot_norm", "T_norm", "HTC_std"]], train_size=0.75)

df_min, df_max = df_train.min(), df_train.max()
df_mean, df_std = df_train.mean(), df_train.std()

df[["QDot_norm", "T_norm"]] = (df[["QDot", "T"]] - df_min[["QDot", "T"]]) / (df_max[["QDot", "T"]] - df_min[["QDot", "T"]])
df["HTC_std"] = (df["HTC"] - df_mean["HTC"]) / df_std["HTC"]

X_train, y_train = df_train[["QDot_norm", "T_norm"]].values, df_train["HTC_std"].values
X_test, y_test = df_test[["QDot_norm", "T_norm"]].values, df_test["HTC_std"].values

# %% [markdown]
# ### model defintion

# %%
m = ( ("s(1)", "inc", 50, (12, 6000), "quantile"), 
      ("s(2)", "peak", 50, (1, 6000), "quantile"), 
      ("t(1,2)", "smooth", (8,8), (1, 100), "equidistant"), )
M = StarModel(description=m)

# %% [markdown]
# ### fit

# %%
M.fit(X=X_train, y=y_train, plot_=0)
print("MSE_train = ", M.mse)
#print("MSE_test = ", M.MSPE(X=X_test, y=y_test))
#M.eval_metric(X=X_test, y=y_test)
# Out:
# MSE_train =  0.2724912

# %% [markdown]
# ### plot

# %%
nplot = 25
xplot = np.linspace(0,1,nplot)
xplotgrid = np.meshgrid(xplot, xplot)
Xplot = np.vstack((xplotgrid[0].ravel(), xplotgrid[1].ravel())).T
yplot = M.predict(X=Xplot)


fig = go.Figure()
#fig.add_trace(go.Scatter3d(x=df["QDot"], y=df["T"], z=df["HTC"], mode="markers", marker=dict(size=2, color="black", symbol="x")))
fig.add_trace(go.Scatter3d(x=df["QDot_norm"], y=df["T_norm"], z=df["HTC_std"], mode="markers", marker=dict(size=2, color="black", symbol="x"), name="data"))
fig.add_trace(go.Scatter3d(x=X_train[:,0], y=X_train[:,1], z=M.basis @ M.coef_, mode="markers", marker=dict(size=2, color="red"), name="fit"))
# fig.add_trace(go.Mesh3d(x=Xplot[:,0], y=Xplot[:,1], z=yplot, name="fit", opacity=0.4, color="red"))
fig.add_trace(go.Surface(x=xplotgrid[0], y=xplotgrid[1], z=yplot.reshape(nplot, nplot)))

fig.layout.scene.xaxis.title = "QDot"
fig.layout.scene.yaxis.title = "T"
fig.layout.scene.zaxis.title = "HTC"
fig.update_layout(height=1000, width=1000)

# %%
M.fit(X=X_train, y=y_train, plot_=0)
M.eval_metric(X=X_test, y=y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-627332f4e03c> in <module>
# ----> 1 M.fit(X=X_train, y=y_train, plot_=0)
#       2 M.eval_metric(X=X_test, y=y_test)
#
# c:\users\jakob\documents\stareg\stareg\star_model.py in fit(self, X, y, plot_, max_iter, cp, weight)
#     205             w = np.ones(X.shape[0])
#     206         X, y = check_X_y(X, y.ravel())
# --> 207         self = self.calc_LS_fit(X=X, y=y)
#     208         df = self.create_df_for_beta(beta_init=self.coef_)
#     209
#
# c:\users\jakob\documents\stareg\stareg\star_model.py in calc_LS_fit(self, X, y)
#     162         """
#     163
# --> 164         self.create_basis(X=X, y=y.ravel())
#     165         fitting = lstsq(a=self.basis, b=y, rcond=None)
#     166         beta_0 = fitting[0].ravel()
#
# c:\users\jakob\documents\stareg\stareg\star_model.py in create_basis(self, X, y)
# ...

# %%
print(M)
# Out:
# {'s(1)': {'constraint': 'inc',
#           'knot_type': 'quantile',
#           'lam': {'constraint': 6000, 'smoothness': 12},
#           'n_param': 50},
#  's(2)': {'constraint': 'peak',
#           'knot_type': 'quantile',
#           'lam': {'constraint': 6000, 'smoothness': 1},
#           'n_param': 50},
#  't(1,2)': {'constraint': 'smooth',
#             'knot_type': 'equidistant',
#             'lam': {'constraint': 100, 'smoothness': 1},
#             'n_param': (8, 8)}}

# %%
from stareg.smooth import Smooths as s
from stareg.smooth import TensorProductSmooths as tps

# %%
X = X_train
y = y_train

# %%
smooths = dict()
for k,v in M.description_dict.items():
    if k.startswith("s"):
        smooths[k] = s(x_data=X[:,int(k[2])-1],  n_param=v["n_param"], constraint=v["constraint"], 
                        y_peak_or_valley=y,lambdas=v["lam"], type_=v["knot_type"])
    elif k.startswith("t"):
        smooths[k] = tps(x_data=X[:, [int(k[2])-1, int(k[4])-1]],  n_param=list(v["n_param"]), 
                        constraint=v["constraint"], lambdas=v["lam"], type_=v["knot_type"])
basis = np.concatenate([v.basis for v in smooths.values()], axis=1)
smoothnes_penalty_list = [v.lam["smoothness"] * v.smoothness for v in smooths.values()]
smoothness_penalty_matrix = block_diag(*smoothnes_penalty_list)
n_coef_list = [0] + [np.product(smooth.n_param) for smooth in smooths.values()]
coef_list = np.cumsum(n_coef_list)
smooths = smooths
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-115-4201b8af2a19> in <module>
#       7         smooths[k] = tps(x_data=X[:, [int(k[2])-1, int(k[4])-1]],  n_param=list(v["n_param"]),
#       8                         constraint=v["constraint"], lambdas=v["lam"], type_=v["knot_type"])
# ----> 9 basis = np.concatenate([v.basis for v in smooths.values()], axis=1)
#      10 smoothnes_penalty_list = [v.lam["smoothness"] * v.smoothness for v in smooths.values()]
#      11 smoothness_penalty_matrix = block_diag(*smoothnes_penalty_list)
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 1680 and the array at index 2 has size 1678

# %%
for v in smooths.values():
    print(v.basis.shape)
# Out:
# (1680, 50)
# (1680, 50)
# (1678, 64)

# %%
X.shape
# Out:
# (1680, 2)

# %%
np.unique(X).reshape(-1,2).shape
# Out:
# (1678, 2)

# %%
df.shape
# Out:
# (2241, 6)

# %%
pd.unique(df[""]).shape
# Out:
# (2241,)

# %%
M.MSPE(X=X_test, y=y_test)
# Out:
# x= [0.36580626 0.9706951 ]
# x= [0.14423222 0.07282887]
# x= [0.16792202 0.7582336 ]
# x= [0.49780741 0.90655376]
# x= [0.10835029 0.02592574]
# x= [0.15187217 0.75328592]
# x= [0.35847565 0.85982966]
# x= [0.18547863 0.50774589]
# x= [0.06854216 0.05318489]
# x= [0.08101657 0.80550947]
# x= [0.19171779 0.48188193]
# x= [0.18642171 0.55568189]
# x= [0.10517172 0.07285696]
# x= [0.06409145 0.11593966]
# x= [0.15386964 0.39629287]
# x= [0.22367508 0.01276734]
# x= [0.34002701 0.58849668]
# x= [0.92750314 0.07337259]
# x= [0.29482421 0.46999176]
# x= [0.29683764 0.88791268]
# x= [0.39642674 0.95122058]
# x= [0.24889871 0.01209009]
# x= [0.37765922 0.54670618]
# x= [0.10660691 0.78653532]
# x= [0.31021095 0.85240011]
# x= [0.14172456 0.4721415 ]
# x= [0.09090704 0.50988433]
# x= [0.14655028 0.38767398]
# x= [0.22469297 0.62631637]
# x= [0.21654169 0.05294425]
# x= [0.22590447 0.9593391 ]
# x= [0.44008421 0.01203571]
# x= [0.20429633 0.9292437 ]
# x= [0.19309168 0.77451722]
# ...

# %%
X_test.max()
# Out:
# 1.0

# %%
M.smooths["s(1)"].knots
# Out:
# array([-0.01923174, -0.01282116, -0.00641058,  0.        ,  0.04621933,
#         0.05824617,  0.06654345,  0.07616356,  0.08635217,  0.09543707,
#         0.10543367,  0.1142786 ,  0.12117191,  0.12949556,  0.13590614,
#         0.14301723,  0.15067005,  0.16169202,  0.17166335,  0.17976466,
#         0.18960291,  0.19908183,  0.20847316,  0.21864533,  0.22915073,
#         0.24013495,  0.25329736,  0.26346109,  0.27899362,  0.29338074,
#         0.30664902,  0.32012722,  0.33239504,  0.3473396 ,  0.37014754,
#         0.38460105,  0.40689846,  0.422095  ,  0.43838841,  0.45541383,
#         0.47475238,  0.49566748,  0.52278318,  0.56694835,  0.59263922,
#         0.62507229,  0.65970814,  0.72767473,  0.8000552 ,  0.88051154,
#         0.9961354 ,  1.00254598,  1.00895656,  1.01536714])
